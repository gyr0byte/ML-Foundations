# %% [markdown]
# # Matplotlib Overview
#
# This notebook covers core Matplotlib plotting patterns:
#
# - Import NumPy, Pandas, and Matplotlib.
# - Create a simple line plot with titles and axis labels.
# - Build a 2x2 subplot grid with multiple line plots.
# - Use the object-oriented API with `figure()` and `add_axes()`.
# - Demonstrate common plot types: scatter, histogram, and box plot.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **<h3>Matplotlib Basics</h3>**

# %%
x = np.linspace(0, 5, 11)
x
y = x ** 2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.title("Line Graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %% [markdown]
# **<h3>Subplots in Matplotlib</h3>**

# %%
plt.subplot(2,2,1)
plt.plot(x,y**2)
plt.subplot(2,2,2)
plt.plot(x**2,x**2)
plt.subplot(2,2,3)
plt.plot(y,x)
plt.subplot(2,2,4)
plt.plot(x,y)

# %% [markdown]
# **<h3>Object Oriented way of plotting</h3>**

# %%
fig = plt.figure(figsize=(10,8), dpi=100)
axis1 = fig.add_axes([0.1,0.1,1,1]) # type: ignore
axis1.plot(x,y)
axis2 = fig.add_axes([0.3,0.1,0.3,0.3]) # type: ignore
axis2.plot(x,y)

# %% [markdown]
# **<h3>Types of plots</h3>**

# %% [markdown]
# **scatter plot**

# %%
plt.scatter(x,y)

# %% [markdown]
# **Histogram**

# %%
from random import sample
data = sample(range(1,1000), 100)
plt.hist(data)
# Out:
# (array([17., 10.,  7.,  9., 11., 10.,  8., 12.,  6., 10.]),
#  array([  5. , 103.9, 202.8, 301.7, 400.6, 499.5, 598.4, 697.3, 796.2,
#         895.1, 994. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# **Box plot**

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f6b0e3d2b0>,
#   <matplotlib.lines.Line2D at 0x1f6b0e3d400>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f6b0e3d550>,
#   <matplotlib.lines.Line2D at 0x1f6b0e3d6a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f6b0e3d160>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f6b0e3d7f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f6b0e3d940>],
#  'means': []}
