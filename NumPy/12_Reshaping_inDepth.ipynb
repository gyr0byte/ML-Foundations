# %%
import numpy as np
arr = np.array([[6, 7], [8, 9], [10, 11]])

# %%
arr
# Out:
# array([[ 6,  7],
#        [ 8,  9],
#        [10, 11]])

# %%
arr.ndim
# Out:
# 2

# %% [markdown]
# **Ravel** -> Converts higher dimensional (2D, 3D, 4D...) arrays into 1D array

# %%
arr.ravel()
# Out:
# array([ 6,  7,  8,  9, 10, 11])

# %% [markdown]
# **Transpose**

# %%
arr.transpose()
# Out:
# array([[ 6,  8, 10],
#        [ 7,  9, 11]])
