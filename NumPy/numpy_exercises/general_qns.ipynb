# %%
import numpy as np
#columns: [age, math marks, science marks]
data = np.array([
    [18, 85, 90], #Students 1
    [19, 78, 88], #Students 2
    [20, 92, 95], #Students 3
    [21, 80, 85], #Students 4
    [22, 88, 92]  #Students 5
])

# %% [markdown]
# **Shape** of the matrix

# %%
data.shape
# Out:
# (5, 3)

# %% [markdown]
# **Age** average

# %%
np.mean(data[:,0])
# Out:
# np.float64(20.0)
