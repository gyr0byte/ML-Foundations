# %%
import numpy as np
#columns: [age, math marks, science marks]
data = np.array([
    [18, 85, 90], #Students 1
    [19, 78, 88], #Students 2
    [20, 92, 95], #Students 3
    [21, 80, 85], #Students 4
    [22, 88, 92]  #Students 5
])

# %% [markdown]
# **Shape** of the matrix

# %%
data.shape
# Out:
# (5, 3)

# %% [markdown]
# **Age** average

# %%
np.mean(data[:,0])
# Out:
# np.float64(20.0)

# %% [markdown]
# Extract **Math** marks of all students

# %%
data[:, 1]
# Out:
# array([85, 78, 92, 80, 88])

# %% [markdown]
# **Highest Science** marks

# %%
np.max(data[:,2])
# Out:
# np.int64(95)

# %% [markdown]
# **Details** of students, marks higher than 90 in **maths**

# %%
data[data[:, 1] > 90]
# Out:
# array([[20, 92, 95]])

# %% [markdown]
# Increase marks of **math** for every student by 5

# %%
data[:,1] + 5
# Out:
# array([90, 83, 97, 85, 93])
