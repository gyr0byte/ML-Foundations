# %%
import numpy as np

a = np.array([1, 2, 3, 4])
b = np.array([0, .5, 1, 1.5, 2])

# acessing the elements in the array 
print(a[0], a[1])
# Out:
# 1 2

# %%
a[::2]
# Out:
# array([1, 3])

# %%
a[1:3]
# Out:
# array([2, 3])

# %%
# Multi indexing
b[[0, 2, -1]]
# Out:
# array([0., 1., 2.])
