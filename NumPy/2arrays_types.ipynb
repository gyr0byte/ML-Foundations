# %% [markdown]
# # Array Types
#
# Run the cells in order.
#
# - The first code cell creates the NumPy arrays `a` and `b`.
# - The next cells show the array value and its data type.
# - If you run a later cell first, you will get a `NameError` because `a` has not been created yet.

# %%
import numpy as np

a = np.array([1, 2, 3, 4])
b = np.array([0, .5, 1, 1.5, 2])

# %%
a
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# Checks the types of array

# %%
a.dtype
# Out:
# dtype('int64')

# %%
b.dtype
# Out:
# dtype('float64')

# %% [markdown]
# **Type conversing in numpy**

# %%
np.array([1, 2, 3, 4], dtype=np.float16)
# Out:
# array([1., 2., 3., 4.], dtype=float16)

# %%
np.array([1, 2, 3, 4], dtype=np.int8)
# Out:
# array([1, 2, 3, 4], dtype=int8)

# %%
c = np.array(['a', 'b', 'c'])
c.dtype
# Out:
# dtype('<U1')
