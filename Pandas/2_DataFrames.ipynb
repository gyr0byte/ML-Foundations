# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. **Creating** a **DataFrame**

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 24, 35, 32],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [50000, 60000, 55000, 65000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   50000
# 1   Anna   24     Paris   60000
# 2  Peter   35    Berlin   55000
# 3  Linda   32    London   65000

# %% [markdown]
# using list

# %%
data_list = [
    ['John', 'Anna', 'Peter', 'Linda'],
    [28, 24, 35, 32],
    ['New York', 'Paris', 'Berlin', 'London'],
    [50000, 60000, 55000, 65000]
]
df2 = pd.DataFrame(data_list)
columns = ["Name", "Age", "City", "Salary"]
df2_columns = pd.DataFrame(data_list, columns= columns)

# %%
df2
# Out:
#           0      1       2       3
# 0      John   Anna   Peter   Linda
# 1        28     24      35      32
# 2  New York  Paris  Berlin  London
# 3     50000  60000   55000   65000

# %%
df2_columns
# Out:
#        Name    Age    City  Salary
# 0      John   Anna   Peter   Linda
# 1        28     24      35      32
# 2  New York  Paris  Berlin  London
# 3     50000  60000   55000   65000

# %% [markdown]
# 2. **Selection** and **Indexing** of a **Column**

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   50000
# 1   Anna   24     Paris   60000
# 2  Peter   35    Berlin   55000
# 3  Linda   32    London   65000

# %% [markdown]
# Targeting a single coumn

# %%
df['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: str

# %% [markdown]
# Targeting multiple columns

# %%
df[['Name','City']]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# 3. **Creating a new column**

# %%
df['Designation'] = ['Doctor', 'Engineer', 'Doctor', 'Engineer']

# %%
df
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   50000      Doctor
# 1   Anna   24     Paris   60000    Engineer
# 2  Peter   35    Berlin   55000      Doctor
# 3  Linda   32    London   65000    Engineer

# %% [markdown]
# 4. **Remove a Column**

# %% [markdown]
# this will not actually remove the coulmn it will show, what the removed colum will look like

# %%
df.drop('Designation', axis=1)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   50000
# 1   Anna   24     Paris   60000
# 2  Peter   35    Berlin   55000
# 3  Linda   32    London   65000

# %%
df
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   50000      Doctor
# 1   Anna   24     Paris   60000    Engineer
# 2  Peter   35    Berlin   55000      Doctor
# 3  Linda   32    London   65000    Engineer

# %% [markdown]
# This will actually remove it

# %%
df.drop('Designation', axis=1, inplace=True) # use axis 0 remove row and axis 1 remove column

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   50000
# 1   Anna   24     Paris   60000
# 2  Peter   35    Berlin   55000
# 3  Linda   32    London   65000

# %% [markdown]
# removing two column at once

# %%
df.drop(['Age','City'], axis=1)
# Out:
#     Name  Salary
# 0   John   50000
# 1   Anna   60000
# 2  Peter   55000
# 3  Linda   65000

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   50000
# 1   Anna   24     Paris   60000
# 2  Peter   35    Berlin   55000
# 3  Linda   32    London   65000

# %% [markdown]
# 5. **Selecting Rows**

# %% [markdown]
# single row selection

# %%
df.loc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       50000
# Name: 0, dtype: object

# %% [markdown]
# multiple row selection

# %%
df.loc[[0, 1]]
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   50000
# 1  Anna   24     Paris   60000

# %% [markdown]
# for getting the index location

# %%
df.iloc[3]
# Out:
# Name       Linda
# Age           32
# City      London
# Salary     65000
# Name: 3, dtype: object

# %% [markdown]
# 6. **Selecting subset of Rows and Columns**

# %%
df.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   50000
# 1     Paris   60000

# %%
df.loc[[2,3]][["Name", "Age"]]
# Out:
#     Name  Age
# 2  Peter   35
# 3  Linda   32
